# %% [markdown]
# ### Pseudocode
# ## What is Pseudocode?
# # Pseudocode is a way of expressing an algorithm without conforming to specific syntax rules.
# # It still has to be precise, unambiguous and allow for the development of a program.
# # It is a good way to start thinking about how a program might be written.
#
# ## Why use Pseudocode?
# # It is a good way to start thinking about how a program might be written.
# # It is a good way to start communicating with others about how a program might be written.
# # It is a good way to start documenting how a program might be written.
#
# # Example in class:
# # On the table I have bread, Peanut Butter (Chunky and Creamy), and jelly.
# # I want to make a Peanut Butter and jelly Sandwich.
# # I have a plate and a knife and a spoon and a plate.
#
# # Pseudocode:
# # inputs = [bread, peanut butter (chunky), jelly, plate, knife, spoon]
# # Actions = Get, Place, Ask, Pickup, Scoop, Spread
# # piece_of_bread = 2
#
# # Ask user would they like pb or jelly first
# # choice = ^
# # for each piece_of_bread:
# # Get bread
# # put bread on plate
# # Ask user what kind of pb they would like
# # if choice == pb:
#     # if user selected chunk
#     # pickup knife and get chunky peanut butter on knife
#         # elif user selected creamy
#     # pickup knife and get creamy peanut butter on knife
#     # Place Knife on bread and spread
# # elif choice == jelly:
#     # Scoop jelly with spoon
#     # Spread jelly on bread
#     # Put Bread with jelly face down on peanut butter
#
# # Get plate
# # Get bread
# # Put bread on plate
# # Ask user would they like pb or jelly first
# # Ask user what kind of pb they would like
# # if user selected chunk
# # pickup knife and get chunky peanut butter on knife
#     # elif user selected creamy
# # pickup knife and get creamy peanut butter on knife
# # Place Knife on bread and spread
# # Put bread on plate
# # Place Knife on plate
# # Pickup Spoon
# # Get bread
# # Put bread on plate
# # Scoop jelly with spoon
# # Spread jelly on bread
# # Put Bread with jelly face down on peanut butter
# # Enjoy!
#
# make_sandwich(bread, peanut butter (chunky), jelly, plate, knife, spoon):
